# %%
# -*- coding: utf-8 -*-
"""
Student Do: Grocery List.

This script showcases basic operations of Python Lists to help Sally
organize her grocery shopping list.
"""

# @TODO: Create a list of groceries

groceries = ['Water', 'Butter', 'Eggs', 'Apples', 'Cinnamon', 'Sugar', 'Milk']



# @TODO: Find the first two items on the list

print(groceries[0:2])


# @TODO: Find the last five items on the list

print(groceries[-5:])


# @TODO: Find every other item on the list, starting from the second item

print(groceries[1::2])


# @TODO: Add an element to the end of the list

groceries.append('Flour')
print(groceries)



# @TODO: Changes a specified element within the list at the given index

groceries[3] = 'Gala Apples'
print(groceries)



# @TODO: Calculate how many items you have in the list

print(len(groceries))
# Out:
# ['Water', 'Butter']
# ['Eggs', 'Apples', 'Cinnamon', 'Sugar', 'Milk']
# ['Butter', 'Apples', 'Sugar']
# ['Water', 'Butter', 'Eggs', 'Apples', 'Cinnamon', 'Sugar', 'Milk', 'Flour']
# ['Water', 'Butter', 'Eggs', 'Gala Apples', 'Cinnamon', 'Sugar', 'Milk', 'Flour']
# 8

# %%
# -*- coding: utf-8 -*-
"""
Student Do: Trading Log.

This script demonstrates how to perform basic analysis of trading profits/losses
over the course of a month (20 business days).
"""

# @TODO: Initialize the metric variables

PNL = 0
count = 0


# @TODO: Initialize lists to hold profitable and unprofitable day profits/losses

profitable_days = []
unprofitable_days = []


# List of trading profits/losses
trading_pnl = [ -224,  352, 252, 354, -544,
                -650,   56, 123, -43,  254,
                 325, -123,  47, 321,  123,
                 133, -151, 613, 232, -311 ]

maximum = max(trading_pnl)
minimum = min(trading_pnl)

# @TODO: Iterate over each element of the list
for x in trading_pnl:

    # @TODO: Cumulatively sum up the total and count
    PNL += x
    count += 1
    # @TODO: Write logic to determine minimum and maximum values
    
    # @TODO: Write logic to determine profitable vs. unprofitable days
    if x >= 0:
        profitable_days.append(x)
    else:
        unprofitable_days.append(x)


# @TODO: Calculate the average
average = round(PNL/count,2)

# @TODO: Calculate count metrics
profitable_count = len(profitable_days)
unprofitable_count = len(unprofitable_days)
# @TODO: Calculate percentage metrics
profitable_percent = profitable_count/count * 100
unprofitable_percent = unprofitable_count/count * 100

# @TODO: Print out the summary statistics
# Out:
# 613
# -650

# %%
# -*- coding: utf-8 -*-
"""
Student Activity: Market Capitalization.
This script showcases the use of Python Dicts to determine the
bank names associated with the corresponding market cap ranges.
"""
# Banks and Market Caps
#-----------------------
# JP Morgan Chase: 327
# Bank of America: 302
# Citigroup: 173
# Wells Fargo: 273
# Goldman Sachs: 87
# Morgan Stanley: 72
# U.S. Bancorp: 83
# TD Bank: 108
# PNC Financial Services: 67
# Capital One: 47
# FNB Corporation: 4
# First Hawaiian Bank: 3
# Ally Financial: 12
# Wachovia: 145
# Republic Bancorp: .97
# @TODO: Initialize a dictionary of banks and market caps (in billions)
banks = {
'JP Morgan Chase': 327,
'Bank of America': 302,
'Citigroup': 173,
'Wells Fargo': 273,
'Goldman Sachs': 87,
'Morgan Stanley': 72,
'U.S. Bancorp': 83,
'TD Bank': 108,
'PNC Financial Services': 67,
'Capital One': 47,
'FNB Corporation': 4,
'First Hawaiian Bank': 3,
'Ally Financial': 12,
'Wachovia': 145,
'Republic Bancorp': .97 }
# @TODO: Change the market cap for 'Citigroup'
banks['Citigroup']=170
# @TODO: Add a new bank and market cap pair
banks['AMEX']=32
# @TODO: Remove a bank from the dictionary
del banks['Wachovia']
# @TODO: Print the modified dictionary
print(banks)

total = 0
count = 0
average = 0 
for x,y in banks.items():
    total += y
    count += 1
    average = total/count
# Out:
# {'JP Morgan Chase': 327, 'Bank of America': 302, 'Citigroup': 170, 'Wells Fargo': 273, 'Goldman Sachs': 87, 'Morgan Stanley': 72, 'U.S. Bancorp': 83, 'TD Bank': 108, 'PNC Financial Services': 67, 'Capital One': 47, 'FNB Corporation': 4, 'First Hawaiian Bank': 3, 'Ally Financial': 12, 'Republic Bancorp': 0.97, 'AMEX': 32}

# %%
a = banks['TD Bank']
print(a)
# Out:
# 108

# %%
banks['TD Bank']=4
print(banks['TD Bank'])
# Out:
# 4

# %%
# -*- coding: utf-8 -*-
"""
Student Activity: Weekly Gains.

This script showcases how to use nested list/dict objects to
calculate weekly gains of stock tickers.
"""

# Dictionary of List of Lists
# Key: Stock Ticker | Value: List of Records
# Record: Date, Open, High, Low, Close
historical_stock_data = {
    "AAPL": [
        ["04-17-2019", 199.54, 203.38, 198.61, 203.13],
        ["04-18-2019", 199.46, 201.37, 198.56, 199.25],
        ["04-19-2019", 198.58, 199.85, 198.01, 199.23],
        ["04-20-2019", 199.20, 200.14, 196.21, 198.87],

    ],
    "MU": [
        ["04-17-2019", 43.20, 43.53, 42.79, 43.40],
        ["04-18-2019", 43.36, 44.05, 42.76, 43.15],
        ["04-19-2019", 42.26, 42.93, 42.08, 42.76],
        ["04-20-2019", 42.17, 42.23, 41.20, 41.82],

    ],
    "AMD": [
        ["04-17-2019", 27.60, 27.88, 27.34, 27.68],
        ["04-18-2019", 28.21, 28.27, 27.22, 27.49],
        ["04-19-2019", 27.72, 28.18, 27.49, 27.93],
        ["04-20-2019", 27.80, 27.84, 26.96, 27.33],

    ],
    "TWTR": [
        ["04-17-2019", 34.67, 34.86, 34.32, 34.40],
        ["04-18-2019", 34.73, 34.90, 34.20, 34.48],
        ["04-19-2019", 34.84, 34.99, 34.23, 34.46],
        ["04-20-2019", 34.38, 35.03, 34.34, 34.71],

    ]
}

# Dictionary of Dictionary
# Key: Stock Ticker | Value: Dictionary
new_records = {
    "AAPL": {
        "date": "04-21-2019",
        "open": 200.85,
        "high": 201.00,
        "low": 198.44,
        "close": 198.95
    },
    "MU": {
        "date": "04-21-2019",
        "open": 42.85,
        "high": 43.20,
        "low": 41.81,
        "close": 42.01
    },
    "AMD": {
        "date": "04-21-2019",
        "open": 28.21,
        "high": 28.38,
        "low": 27.66,
        "close": 27.85
    },
    "TWTR": {
        "date": "04-21-2019",
        "open": 34.67,
        "high": 34.83,
        "low": 34.11,
        "close": 34.37
    }
}

# @TODO: Set each ticker's new record: date, open, high, low, close
for a, b in new_records.items():
    for x, y in historical_stock_data.items():
        if x == a:
            y.append([b["date"],b["open"],b["high"],b["low"],b["close"]])

print(historical_stock_data)
            




# @TODO: Choice 1: Add a new round of entries to the 'historical_stock_data' dictionary
results = {}
beginning_weekly_close = 0.0
ending_weekly_close = 0.0
ticker_weekly_close = 0.0

for x, y in historical_stock_data.items():
    beginning_weekly_close = y[0][4]
    ending_weekly_close = y[4][4]
    ticker_weekly_close = (ending_weekly_close - beginning_weekly_close) / beginning_weekly_close * 100
    results[x] = round(ticker_weekly_close, 2)

print(results)

# @TODO: Choice 2: Add a new round of entries via for loop to the 'historical_stock_data' dictionary






# @TODO: Print out the modified 'historical_stock_data' dictionary
# Out:
# {'AAPL': [['04-17-2019', 199.54, 203.38, 198.61, 203.13], ['04-18-2019', 199.46, 201.37, 198.56, 199.25], ['04-19-2019', 198.58, 199.85, 198.01, 199.23], ['04-20-2019', 199.2, 200.14, 196.21, 198.87], ['04-21-2019', 200.85, 201.0, 198.44, 198.95]], 'MU': [['04-17-2019', 43.2, 43.53, 42.79, 43.4], ['04-18-2019', 43.36, 44.05, 42.76, 43.15], ['04-19-2019', 42.26, 42.93, 42.08, 42.76], ['04-20-2019', 42.17, 42.23, 41.2, 41.82], ['04-21-2019', 42.85, 43.2, 41.81, 42.01]], 'AMD': [['04-17-2019', 27.6, 27.88, 27.34, 27.68], ['04-18-2019', 28.21, 28.27, 27.22, 27.49], ['04-19-2019', 27.72, 28.18, 27.49, 27.93], ['04-20-2019', 27.8, 27.84, 26.96, 27.33], ['04-21-2019', 28.21, 28.38, 27.66, 27.85]], 'TWTR': [['04-17-2019', 34.67, 34.86, 34.32, 34.4], ['04-18-2019', 34.73, 34.9, 34.2, 34.48], ['04-19-2019', 34.84, 34.99, 34.23, 34.46], ['04-20-2019', 34.38, 35.03, 34.34, 34.71], ['04-21-2019', 34.67, 34.83, 34.11, 34.37]]}
# {'AAPL': -2.06, 'MU': -3.2, 'AMD': 0.61, 'TWTR': -0.09}
